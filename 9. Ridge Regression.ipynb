# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge

# %%
x = pd.read_csv("C:/Datasets/train.csv")
x.head()
# Out:
#    Weight  Height
# 0      40     4.0
# 1      46     4.5
# 2      50     4.7
# 3      60     5.0
# 4      62     5.1

# %%
y = pd.read_csv("c:/Datasets/test.csv")
y.head()
# Out:
#    Weight  Height
# 0      66     5.5
# 1      65     5.7
# 2      69     5.9
# 3      70     6.2
# 4      73     6.8

# %%
w_train = x.iloc[:, 0:1].values
h_train = x.iloc[:, 1].values
w_test = y.iloc[:, 0:1].values
h_test = y.iloc[: , 1].values

# %%
plt.scatter(w_train, h_train, color = "blue", marker = "o")
plt.show()

# %%
plt.scatter(w_test, w_test, color = "red", marker = "d")
plt.show()

# %%
lr = LinearRegression()
lr.fit(w_train, h_train)
# Out:
# LinearRegression()

# %%
lr.score(w_train, h_train)
# Out:
# 0.9554154968329801

# %%
plt.scatter(w_train, h_train, color = "blue")
plt.plot(w_train, lr.predict(w_train), color = "orange")
plt.show()

# %%
rr = Ridge(alpha = 0.001)
rr.fit(w_test, h_test)
# Out:
# Ridge(alpha=0.001)

# %%
rr.score(w_test, h_test)
# Out:
# 0.8901155976774442

# %%
plt.scatter(w_test, h_test, color = "red")
plt.plot(w_test, rr.predict(w_test), color = "green")
plt.show()

# %%
rr.predict([[70.3]])
# Out:
# array([6.27334337])
