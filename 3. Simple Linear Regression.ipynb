# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("c:/Datasets/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
sns.scatterplot(data = df, x = "area", y = "price")
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
reg = LinearRegression()
reg.fit(df[["area"]], df["price"])
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\Users\MOHIT SINGH\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
y = 135.7867123 * 3300 + 180616.43835616432
y
# Out:
# 628712.5889461644

# %%
reg.predict([[5000]])
# Out:
# c:\Users\MOHIT SINGH\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
from sklearn.metrics import r2_score
y_original = df.price
y_predicted = reg.predict(df[["area"]])
R_square = r2_score(y_original, y_predicted)
print("r squared value :", R_square)
# Out:
# r squared value : 0.9584301138199486

# %%
sns.lmplot(data = df, x = "area", y = "price")
