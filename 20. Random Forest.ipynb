# %%
import pandas as pd
df = pd.read_csv("C:/Datasets/Salary_Experience.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
x = df.iloc[:, 0 : 1]
y = df["Salary"].values

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(x, y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
regressor.score(x, y)
# Out:
# 0.9923669456643155

# %%
regressor.predict([[4.2]])
# Out:
# c:\Users\MOHIT SINGH\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([56932.77516667])

# %%
regressor.predict([[7]])
# Out:
# c:\Users\MOHIT SINGH\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([98687.5])

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y, color = "blue")
plt.plot(x, regressor.predict(x), color = "red")
plt.title("Random Forest Regression")
plt.xlabel("Experience level")
plt.ylabel("Salary")
plt.show()
