# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Datasets/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
x = df[["age"]]
x.head()
# Out:
#    age
# 0   22
# 1   25
# 2   47
# 3   52
# 4   46

# %%
y = df["bought_insurance"]
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: bought_insurance, dtype: int64

# %%
plt.xlabel("Age")
plt.ylabel("Have insurance?")
plt.scatter(x, y, marker = "+", color = "red")
plt.show()

# %%
import seaborn as sns
sns.regplot(x = "age", y = "bought_insurance", data = df, logistic = True, marker = "+", color = "red")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x, y)
# Out:
# LogisticRegression()

# %%
model.score(x, y)
# Out:
# 0.8888888888888888

# %%
model.predict([[56]])
# Out:
# c:\Users\MOHIT SINGH\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.predict([[36]])
# Out:
# c:\Users\MOHIT SINGH\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
